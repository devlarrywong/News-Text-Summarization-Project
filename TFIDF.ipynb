# %% [markdown]
# # Process Text using TFIDF in Python

# %% [markdown]
# ref: https://towardsdatascience.com/tfidf-for-piece-of-text-in-python-43feccaa74f8

# %%
import nltk
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
import math

# %%
text = """
If you like tuna and tomato sauce- try combining the two.
It's really not as bad as it sounds.
If the Easter Bunny and the Tooth Fairy had babies world they take
your teeth and leave chocolate for you?
"""

# %% [markdown]
# # Simple Pre-processing

# %%
def remove_string_special_characters(s):
    """
    This function removes special characters from within a string
    
    parameters:
        s(str): single input string.
        
    return:
        stripped(str): A string with special characters removed
    """
    
    # Replace special character with ' '
    stripped = re.sub('[^\w\s]', '', s)
    stripped = re.sub('_', '', stripped)
    
    # Change any whitespace to one space
    stripped = re.sub('\s+', ' ', stripped)
    
    # Remove start and end white spaces
    stripped = stripped.strip()
    
    return stripped

# %% [markdown]
# # Create a documents

# %%
def get_doc(sent):
    """
    this function splits the text into sentences and
    considering each sentence as a document, calculates the
    total word count of each.
    """
    
    doc_info = []
    i = 0
    for sent in text_sents_clean:
        i += 1
        count = count_words(sent)
        temp = {'doc_id': i, 'doc_length': count}
        doc_info.append(temp)
    return doc_info

# %% [markdown]
# # Pre-requisite to calculating the TF and IDF scores

# %%
def count_words(sent):
    """This function returns the 
    total number of words in the input text
    """
    count = 0
    words = word_tokenize(sent)
    for word in words:
        count += 1
    return count

# %%
def create_freq_dict(sents):
    """
    This function creates a frequency dictionary
    for each word in each document.
    """
    i = 0
    freqDict_list = []
    for sent in sents:
        i += 1
        freq_dict = {}
        words = word_tokenize(sent)
        for word in words:
            word = word.lower()
            if word in freq_dict:
                freq_dict[word] += 1
            else:
                freq_dict[word] = 1
            temp = {'doc_id':i, 'freq_dict':freq_dict}
        freqDict_list.append(temp)
    return freqDict_list

# %% [markdown]
# # The functions to get the TF and IDF score

# %%
def computeTF(doc_info, freqDict_list):
    """
    tf = (frequency of the term in the doc/total number of terms in the doc)
    """
    TF_scores = []
    for tempDict in freqDict_list:
        id = tempDict['doc_id']
        for k in tempDict['freq_dict']:
            temp = {
                'doc_id': id,
                'TF_score': tempDict['freq_dict'][k]/doc_info[id-1]['doc_length'],
                'key':k
            }
            TF_scores.append(temp)
    return TF_scores

# %%
def computeIDF(doc_info, freqDict_list):
    """
    idf = ln(total number of docs/number of docs with term in it)
    """
    IDF_scores = []
    counter = 0
    for dict in freqDict_list:
        counter += 1
        for k in dict['freq_dict'].keys():
            count = sum([k in tempDict['freq_dict'] for tempDict in freqDict_list])
            temp = {'doc_id': counter, 'IDF_score': math.log(len(doc_info)/count), 'key':k}
            
            IDF_scores.append(temp)
    return IDF_scores

# %% [markdown]
# # Combine

# %%
def computeTFIDF(TF_scores, IDF_scores):
    TFIDF_scores = []
    for j in IDF_scores:
        for i in TF_scores:
            if j['key'] == i['key'] and j['doc_id'] == i['doc_id']:
                temp = {'doc_id':j['doc_id'],
                        'TFIDF_score':j['IDF_score']*i['TF_score'],
                        'key':i['key']
                       }
        TFIDF_scores.append(temp)
    return TFIDF_scores

# %%
text_sents = sent_tokenize(text)
text_sents_clean = [remove_string_special_characters(s) for s in text_sents]
doc_info = get_doc(text_sents_clean)

# %%
freqDict_list = create_freq_dict(text_sents_clean)
TF_scores = computeTF(doc_info, freqDict_list)
IDF_scores = computeIDF(doc_info, freqDict_list)

# %%
doc_info
# Out:
# [{'doc_id': 1, 'doc_length': 11},
#  {'doc_id': 2, 'doc_length': 8},
#  {'doc_id': 3, 'doc_length': 20}]

# %%
freqDict_list
# Out:
# [{'doc_id': 1,
#   'freq_dict': {'if': 1,
#    'you': 1,
#    'like': 1,
#    'tuna': 1,
#    'and': 1,
#    'tomato': 1,
#    'sauce': 1,
#    'try': 1,
#    'combining': 1,
#    'the': 1,
#    'two': 1}},
#  {'doc_id': 2,
#   'freq_dict': {'its': 1,
#    'really': 1,
#    'not': 1,
#    'as': 2,
#    'bad': 1,
#    'it': 1,
#    'sounds': 1}},
#  {'doc_id': 3,
#   'freq_dict': {'if': 1,
#    'the': 2,
#    'easter': 1,
#    'bunny': 1,
#    'and': 2,
#    'tooth': 1,
#    'fairy': 1,
#    'had': 1,
#    'babies': 1,
#    'world': 1,
#    'they': 1,
#    'take': 1,
#    'your': 1,
#    'teeth': 1,
#    'leave': 1,
#    'chocolate': 1,
#    'for': 1,
#    'you': 1}}]

# %%
TF_scores
# Out:
# [{'doc_id': 1, 'TF_score': 0.09090909090909091, 'key': 'if'},
#  {'doc_id': 1, 'TF_score': 0.09090909090909091, 'key': 'you'},
#  {'doc_id': 1, 'TF_score': 0.09090909090909091, 'key': 'like'},
#  {'doc_id': 1, 'TF_score': 0.09090909090909091, 'key': 'tuna'},
#  {'doc_id': 1, 'TF_score': 0.09090909090909091, 'key': 'and'},
#  {'doc_id': 1, 'TF_score': 0.09090909090909091, 'key': 'tomato'},
#  {'doc_id': 1, 'TF_score': 0.09090909090909091, 'key': 'sauce'},
#  {'doc_id': 1, 'TF_score': 0.09090909090909091, 'key': 'try'},
#  {'doc_id': 1, 'TF_score': 0.09090909090909091, 'key': 'combining'},
#  {'doc_id': 1, 'TF_score': 0.09090909090909091, 'key': 'the'},
#  {'doc_id': 1, 'TF_score': 0.09090909090909091, 'key': 'two'},
#  {'doc_id': 2, 'TF_score': 0.125, 'key': 'its'},
#  {'doc_id': 2, 'TF_score': 0.125, 'key': 'really'},
#  {'doc_id': 2, 'TF_score': 0.125, 'key': 'not'},
#  {'doc_id': 2, 'TF_score': 0.25, 'key': 'as'},
#  {'doc_id': 2, 'TF_score': 0.125, 'key': 'bad'},
#  {'doc_id': 2, 'TF_score': 0.125, 'key': 'it'},
#  {'doc_id': 2, 'TF_score': 0.125, 'key': 'sounds'},
#  {'doc_id': 3, 'TF_score': 0.05, 'key': 'if'},
#  {'doc_id': 3, 'TF_score': 0.1, 'key': 'the'},
#  {'doc_id': 3, 'TF_score': 0.05, 'key': 'easter'},
#  {'doc_id': 3, 'TF_score': 0.05, 'key': 'bunny'},
#  {'doc_id': 3, 'TF_score': 0.1, 'key': 'and'},
#  {'doc_id': 3, 'TF_score': 0.05, 'key': 'tooth'},
#  {'doc_id': 3, 'TF_score': 0.05, 'key': 'fairy'},
#  {'doc_id': 3, 'TF_score': 0.05, 'key': 'had'},
#  {'doc_id': 3, 'TF_score': 0.05, 'key': 'babies'},
#  {'doc_id': 3, 'TF_score': 0.05, 'key': 'world'},
#  {'doc_id': 3, 'TF_score': 0.05, 'key': 'they'},
#  {'doc_id': 3, 'TF_score': 0.05, 'key': 'take'},
#  {'doc_id': 3, 'TF_score': 0.05, 'key': 'your'},
#  {'doc_id': 3, 'TF_score': 0.05, 'key': 'teeth'},
#  {'doc_id': 3, 'TF_score': 0.05, 'key': 'leave'},
#  {'doc_id': 3, 'TF_score': 0.05, 'key': 'chocolate'},
#  {'doc_id': 3, 'TF_score': 0.05, 'key': 'for'},
#  {'doc_id': 3, 'TF_score': 0.05, 'key': 'you'}]

# %%
IDF_scores
# Out:
# [{'doc_id': 1, 'IDF_score': 0.4054651081081644, 'key': 'if'},
#  {'doc_id': 1, 'IDF_score': 0.4054651081081644, 'key': 'you'},
#  {'doc_id': 1, 'IDF_score': 1.0986122886681098, 'key': 'like'},
#  {'doc_id': 1, 'IDF_score': 1.0986122886681098, 'key': 'tuna'},
#  {'doc_id': 1, 'IDF_score': 0.4054651081081644, 'key': 'and'},
#  {'doc_id': 1, 'IDF_score': 1.0986122886681098, 'key': 'tomato'},
#  {'doc_id': 1, 'IDF_score': 1.0986122886681098, 'key': 'sauce'},
#  {'doc_id': 1, 'IDF_score': 1.0986122886681098, 'key': 'try'},
#  {'doc_id': 1, 'IDF_score': 1.0986122886681098, 'key': 'combining'},
#  {'doc_id': 1, 'IDF_score': 0.4054651081081644, 'key': 'the'},
#  {'doc_id': 1, 'IDF_score': 1.0986122886681098, 'key': 'two'},
#  {'doc_id': 2, 'IDF_score': 1.0986122886681098, 'key': 'its'},
#  {'doc_id': 2, 'IDF_score': 1.0986122886681098, 'key': 'really'},
#  {'doc_id': 2, 'IDF_score': 1.0986122886681098, 'key': 'not'},
#  {'doc_id': 2, 'IDF_score': 1.0986122886681098, 'key': 'as'},
#  {'doc_id': 2, 'IDF_score': 1.0986122886681098, 'key': 'bad'},
#  {'doc_id': 2, 'IDF_score': 1.0986122886681098, 'key': 'it'},
#  {'doc_id': 2, 'IDF_score': 1.0986122886681098, 'key': 'sounds'},
#  {'doc_id': 3, 'IDF_score': 0.4054651081081644, 'key': 'if'},
#  {'doc_id': 3, 'IDF_score': 0.4054651081081644, 'key': 'the'},
#  {'doc_id': 3, 'IDF_score': 1.0986122886681098, 'key': 'easter'},
#  {'doc_id': 3, 'IDF_score': 1.0986122886681098, 'key': 'bunny'},
#  {'doc_id': 3, 'IDF_score': 0.4054651081081644, 'key': 'and'},
#  {'doc_id': 3, 'IDF_score': 1.0986122886681098, 'key': 'tooth'},
#  {'doc_id': 3, 'IDF_score': 1.0986122886681098, 'key': 'fairy'},
#  {'doc_id': 3, 'IDF_score': 1.0986122886681098, 'key': 'had'},
#  {'doc_id': 3, 'IDF_score': 1.0986122886681098, 'key': 'babies'},
#  {'doc_id': 3, 'IDF_score': 1.0986122886681098, 'key': 'world'},
#  {'doc_id': 3, 'IDF_score': 1.0986122886681098, 'key': 'they'},
#  {'doc_id': 3, 'IDF_score': 1.0986122886681098, 'key': 'take'},
#  {'doc_id': 3, 'IDF_score': 1.0986122886681098, 'key': 'your'},
#  {'doc_id': 3, 'IDF_score': 1.0986122886681098, 'key': 'teeth'},
#  {'doc_id': 3, 'IDF_score': 1.0986122886681098, 'key': 'leave'},
#  {'doc_id': 3, 'IDF_score': 1.0986122886681098, 'key': 'chocolate'},
#  {'doc_id': 3, 'IDF_score': 1.0986122886681098, 'key': 'for'},
#  {'doc_id': 3, 'IDF_score': 0.4054651081081644, 'key': 'you'}]

# %%
TFIDF_scores = computeTFIDF(TF_scores, IDF_scores)
TFIDF_scores
# Out:
# [{'doc_id': 1, 'TFIDF_score': 0.036860464373469494, 'key': 'if'},
#  {'doc_id': 1, 'TFIDF_score': 0.036860464373469494, 'key': 'you'},
#  {'doc_id': 1, 'TFIDF_score': 0.09987384442437362, 'key': 'like'},
#  {'doc_id': 1, 'TFIDF_score': 0.09987384442437362, 'key': 'tuna'},
#  {'doc_id': 1, 'TFIDF_score': 0.036860464373469494, 'key': 'and'},
#  {'doc_id': 1, 'TFIDF_score': 0.09987384442437362, 'key': 'tomato'},
#  {'doc_id': 1, 'TFIDF_score': 0.09987384442437362, 'key': 'sauce'},
#  {'doc_id': 1, 'TFIDF_score': 0.09987384442437362, 'key': 'try'},
#  {'doc_id': 1, 'TFIDF_score': 0.09987384442437362, 'key': 'combining'},
#  {'doc_id': 1, 'TFIDF_score': 0.036860464373469494, 'key': 'the'},
#  {'doc_id': 1, 'TFIDF_score': 0.09987384442437362, 'key': 'two'},
#  {'doc_id': 2, 'TFIDF_score': 0.13732653608351372, 'key': 'its'},
#  {'doc_id': 2, 'TFIDF_score': 0.13732653608351372, 'key': 'really'},
#  {'doc_id': 2, 'TFIDF_score': 0.13732653608351372, 'key': 'not'},
#  {'doc_id': 2, 'TFIDF_score': 0.27465307216702745, 'key': 'as'},
#  {'doc_id': 2, 'TFIDF_score': 0.13732653608351372, 'key': 'bad'},
#  {'doc_id': 2, 'TFIDF_score': 0.13732653608351372, 'key': 'it'},
#  {'doc_id': 2, 'TFIDF_score': 0.13732653608351372, 'key': 'sounds'},
#  {'doc_id': 3, 'TFIDF_score': 0.02027325540540822, 'key': 'if'},
#  {'doc_id': 3, 'TFIDF_score': 0.04054651081081644, 'key': 'the'},
#  {'doc_id': 3, 'TFIDF_score': 0.054930614433405495, 'key': 'easter'},
#  {'doc_id': 3, 'TFIDF_score': 0.054930614433405495, 'key': 'bunny'},
#  {'doc_id': 3, 'TFIDF_score': 0.04054651081081644, 'key': 'and'},
#  {'doc_id': 3, 'TFIDF_score': 0.054930614433405495, 'key': 'tooth'},
#  {'doc_id': 3, 'TFIDF_score': 0.054930614433405495, 'key': 'fairy'},
#  {'doc_id': 3, 'TFIDF_score': 0.054930614433405495, 'key': 'had'},
#  {'doc_id': 3, 'TFIDF_score': 0.054930614433405495, 'key': 'babies'},
#  {'doc_id': 3, 'TFIDF_score': 0.054930614433405495, 'key': 'world'},
#  {'doc_id': 3, 'TFIDF_score': 0.054930614433405495, 'key': 'they'},
#  {'doc_id': 3, 'TFIDF_score': 0.054930614433405495, 'key': 'take'},
#  {'doc_id': 3, 'TFIDF_score': 0.054930614433405495, 'key': 'your'},
#  {'doc_id': 3, 'TFIDF_score': 0.054930614433405495, 'key': 'teeth'},
#  {'doc_id': 3, 'TFIDF_score': 0.054930614433405495, 'key': 'leave'},
#  {'doc_id': 3, 'TFIDF_score': 0.054930614433405495, 'key': 'chocolate'},
#  {'doc_id': 3, 'TFIDF_score': 0.054930614433405495, 'key': 'for'},
#  {'doc_id': 3, 'TFIDF_score': 0.02027325540540822, 'key': 'you'}]

# %% [markdown]
# ---

# %% [markdown]
# # Summarise Text with TFIDF in Python

# %% [markdown]
# text.txt ref: https://www.bbc.com/news/world-asia-china-44816715
# Medium ref: https://medium.com/@shivangisareen/summarise-text-with-tfidf-in-python-bc7ca10d3284

# %%
def get_doc2(sent):
    """
    this function splits the text into sentences and
    considering each sentence as a document, calculates the
    total word count of each.
    """
    
    doc_info = []
    i = 0
    for sent in second_text_sents_clean:
        i += 1
        count = count_words(sent)
        temp = {'doc_id': i, 'doc_length': count}
        doc_info.append(temp)
    return doc_info

# %%
with open('text.txt') as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 
content = ' '.join(content)

# %%
second_text_sents = sent_tokenize(content)
second_text_sents_clean = [remove_string_special_characters(s) for s in second_text_sents]
second_doc_info = get_doc2(second_text_sents_clean)

# %%
second_freqDict_list = create_freq_dict(second_text_sents_clean)
second_TF_scores = computeTF(second_doc_info, second_freqDict_list)
second_IDF_scores = computeIDF(second_doc_info, second_freqDict_list)

# %%
second_doc_info
# Out:
# [{'doc_id': 1, 'doc_length': 21},
#  {'doc_id': 2, 'doc_length': 24},
#  {'doc_id': 3, 'doc_length': 17},
#  {'doc_id': 4, 'doc_length': 8},
#  {'doc_id': 5, 'doc_length': 18},
#  {'doc_id': 6, 'doc_length': 10},
#  {'doc_id': 7, 'doc_length': 9},
#  {'doc_id': 8, 'doc_length': 10},
#  {'doc_id': 9, 'doc_length': 24},
#  {'doc_id': 10, 'doc_length': 11},
#  {'doc_id': 11, 'doc_length': 19},
#  {'doc_id': 12, 'doc_length': 25}]

# %%
second_freqDict_list
# Out:
# [{'doc_id': 1,
#   'freq_dict': {'an': 2,
#    'explosion': 1,
#    'at': 1,
#    'industrial': 1,
#    'park': 1,
#    'in': 1,
#    'chinas': 1,
#    'sichuan': 1,
#    'province': 1,
#    'has': 1,
#    'left': 1,
#    '19': 1,
#    'people': 1,
#    'dead': 1,
#    'and': 1,
#    '12': 1,
#    'others': 1,
#    'injured': 1,
#    'officials': 1,
#    'say': 1}},
#  {'doc_id': 2,
#   'freq_dict': {'in': 2,
#    'a': 2,
#    'statement': 1,
#    'quoted': 1,
#    'by': 2,
#    'reuters': 1,
#    'the': 2,
#    'authorities': 1,
#    'jiangan': 1,
#    'county': 1,
#    'said': 1,
#    'blast': 1,
#    'happened': 1,
#    'at': 1,
#    'chemical': 1,
#    'plant': 1,
#    'run': 1,
#    'yibin': 1,
#    'hengda': 1,
#    'technology': 1}},
#  {'doc_id': 3,
#   'freq_dict': {'photos': 1,
#    'on': 1,
#    'chinese': 1,
#    'social': 1,
#    'media': 1,
#    'showed': 1,
#    'a': 1,
#    'huge': 1,
#    'fire': 1,
#    'and': 1,
#    'plumes': 1,
#    'of': 1,
#    'smoke': 1,
#    'rising': 1,
#    'from': 1,
#    'the': 1,
#    'facility': 1}},
#  {'doc_id': 4,
#   'freq_dict': {'it': 1,
#    'is': 1,
#    'not': 1,
#    'clear': 1,
#    'what': 1,
#    'caused': 1,
#    'the': 1,
#    'explosion': 1}},
#  {'doc_id': 5,
#   'freq_dict': {'according': 1,
#    'to': 1,
#    'xinhua': 1,
#    'the': 1,
#    'fire': 1,
#    'which': 1,
#    'broke': 1,
#    'out': 2,
#    'on': 2,
#    'thursday': 1,
#    'evening': 1,
#    'had': 1,
#    'been': 1,
#    'put': 1,
#    'early': 1,
#    'friday': 1}},
#  {'doc_id': 6,
#   'freq_dict': {'those': 1,
#    'injured': 1,
#    'in': 2,
#    'the': 1,
#    'blast': 1,
#    'were': 1,
#    'a': 1,
#    'stable': 1,
#    'condition': 1}},
#  {'doc_id': 7,
#   'freq_dict': {'authorities': 1,
#    'have': 1,
#    'begun': 1,
#    'an': 1,
#    'investigation': 1,
#    'the': 1,
#    'news': 1,
#    'agency': 1,
#    'said': 1}},
#  {'doc_id': 8,
#   'freq_dict': {'yibin': 1,
#    'hengda': 1,
#    'makes': 1,
#    'chemicals': 1,
#    'for': 1,
#    'the': 1,
#    'food': 1,
#    'and': 1,
#    'pharmaceutical': 1,
#    'industries': 1}},
#  {'doc_id': 9,
#   'freq_dict': {'according': 1,
#    'to': 2,
#    'local': 1,
#    'media': 1,
#    'reports': 1,
#    'the': 2,
#    'threestorey': 1,
#    'buildings': 2,
#    'of': 1,
#    'factory': 1,
#    'burnt': 1,
#    'down': 1,
#    'their': 2,
#    'steel': 1,
#    'frames': 1,
#    'and': 1,
#    'nearby': 1,
#    'had': 1,
#    'windows': 1,
#    'shattered': 1}},
#  {'doc_id': 10,
#   'freq_dict': {'the': 1,
#    'accident': 1,
#    'follows': 1,
#    'previous': 1,
#    'highprofile': 1,
#    'disasters': 1,
#    'at': 1,
#    'chemical': 1,
#    'plants': 1,
#    'in': 1,
#    'china': 1}},
#  {'doc_id': 11,
#   'freq_dict': {'in': 3,
#    '2015': 1,
#    '173': 1,
#    'people': 1,
#    'died': 1,
#    'an': 1,
#    'explosion': 1,
#    'at': 1,
#    'a': 1,
#    'chemical': 1,
#    'warehouse': 1,
#    'the': 1,
#    'northeastern': 1,
#    'port': 1,
#    'city': 1,
#    'of': 1,
#    'tianjin': 1}},
#  {'doc_id': 12,
#   'freq_dict': {'an': 1,
#    'official': 2,
#    'investigation': 1,
#    'into': 1,
#    'the': 1,
#    'blast': 1,
#    'found': 1,
#    'that': 1,
#    'corruption': 1,
#    'political': 1,
#    'connections': 1,
#    'and': 2,
#    'collusion': 1,
#    'allowed': 1,
#    'corners': 1,
#    'to': 2,
#    'be': 2,
#    'cut': 1,
#    'safety': 1,
#    'systems': 1,
#    'overridden': 1}}]

# %%
second_TF_scores
# Out:
# [{'doc_id': 1, 'TF_score': 0.09523809523809523, 'key': 'an'},
#  {'doc_id': 1, 'TF_score': 0.047619047619047616, 'key': 'explosion'},
#  {'doc_id': 1, 'TF_score': 0.047619047619047616, 'key': 'at'},
#  {'doc_id': 1, 'TF_score': 0.047619047619047616, 'key': 'industrial'},
#  {'doc_id': 1, 'TF_score': 0.047619047619047616, 'key': 'park'},
#  {'doc_id': 1, 'TF_score': 0.047619047619047616, 'key': 'in'},
#  {'doc_id': 1, 'TF_score': 0.047619047619047616, 'key': 'chinas'},
#  {'doc_id': 1, 'TF_score': 0.047619047619047616, 'key': 'sichuan'},
#  {'doc_id': 1, 'TF_score': 0.047619047619047616, 'key': 'province'},
#  {'doc_id': 1, 'TF_score': 0.047619047619047616, 'key': 'has'},
#  {'doc_id': 1, 'TF_score': 0.047619047619047616, 'key': 'left'},
#  {'doc_id': 1, 'TF_score': 0.047619047619047616, 'key': '19'},
#  {'doc_id': 1, 'TF_score': 0.047619047619047616, 'key': 'people'},
#  {'doc_id': 1, 'TF_score': 0.047619047619047616, 'key': 'dead'},
#  {'doc_id': 1, 'TF_score': 0.047619047619047616, 'key': 'and'},
#  {'doc_id': 1, 'TF_score': 0.047619047619047616, 'key': '12'},
#  {'doc_id': 1, 'TF_score': 0.047619047619047616, 'key': 'others'},
#  {'doc_id': 1, 'TF_score': 0.047619047619047616, 'key': 'injured'},
#  {'doc_id': 1, 'TF_score': 0.047619047619047616, 'key': 'officials'},
#  {'doc_id': 1, 'TF_score': 0.047619047619047616, 'key': 'say'},
#  {'doc_id': 2, 'TF_score': 0.08333333333333333, 'key': 'in'},
#  {'doc_id': 2, 'TF_score': 0.08333333333333333, 'key': 'a'},
#  {'doc_id': 2, 'TF_score': 0.041666666666666664, 'key': 'statement'},
#  {'doc_id': 2, 'TF_score': 0.041666666666666664, 'key': 'quoted'},
#  {'doc_id': 2, 'TF_score': 0.08333333333333333, 'key': 'by'},
#  {'doc_id': 2, 'TF_score': 0.041666666666666664, 'key': 'reuters'},
#  {'doc_id': 2, 'TF_score': 0.08333333333333333, 'key': 'the'},
#  {'doc_id': 2, 'TF_score': 0.041666666666666664, 'key': 'authorities'},
#  {'doc_id': 2, 'TF_score': 0.041666666666666664, 'key': 'jiangan'},
#  {'doc_id': 2, 'TF_score': 0.041666666666666664, 'key': 'county'},
#  {'doc_id': 2, 'TF_score': 0.041666666666666664, 'key': 'said'},
#  {'doc_id': 2, 'TF_score': 0.041666666666666664, 'key': 'blast'},
#  {'doc_id': 2, 'TF_score': 0.041666666666666664, 'key': 'happened'},
#  {'doc_id': 2, 'TF_score': 0.041666666666666664, 'key': 'at'},
#  {'doc_id': 2, 'TF_score': 0.041666666666666664, 'key': 'chemical'},
#  {'doc_id': 2, 'TF_score': 0.041666666666666664, 'key': 'plant'},
#  {'doc_id': 2, 'TF_score': 0.041666666666666664, 'key': 'run'},
#  {'doc_id': 2, 'TF_score': 0.041666666666666664, 'key': 'yibin'},
#  {'doc_id': 2, 'TF_score': 0.041666666666666664, 'key': 'hengda'},
#  {'doc_id': 2, 'TF_score': 0.041666666666666664, 'key': 'technology'},
#  {'doc_id': 3, 'TF_score': 0.058823529411764705, 'key': 'photos'},
#  {'doc_id': 3, 'TF_score': 0.058823529411764705, 'key': 'on'},
#  {'doc_id': 3, 'TF_score': 0.058823529411764705, 'key': 'chinese'},
#  {'doc_id': 3, 'TF_score': 0.058823529411764705, 'key': 'social'},
#  {'doc_id': 3, 'TF_score': 0.058823529411764705, 'key': 'media'},
#  {'doc_id': 3, 'TF_score': 0.058823529411764705, 'key': 'showed'},
#  {'doc_id': 3, 'TF_score': 0.058823529411764705, 'key': 'a'},
#  {'doc_id': 3, 'TF_score': 0.058823529411764705, 'key': 'huge'},
#  {'doc_id': 3, 'TF_score': 0.058823529411764705, 'key': 'fire'},
#  {'doc_id': 3, 'TF_score': 0.058823529411764705, 'key': 'and'},
#  {'doc_id': 3, 'TF_score': 0.058823529411764705, 'key': 'plumes'},
#  {'doc_id': 3, 'TF_score': 0.058823529411764705, 'key': 'of'},
#  {'doc_id': 3, 'TF_score': 0.058823529411764705, 'key': 'smoke'},
#  {'doc_id': 3, 'TF_score': 0.058823529411764705, 'key': 'rising'},
#  {'doc_id': 3, 'TF_score': 0.058823529411764705, 'key': 'from'},
#  {'doc_id': 3, 'TF_score': 0.058823529411764705, 'key': 'the'},
#  {'doc_id': 3, 'TF_score': 0.058823529411764705, 'key': 'facility'},
#  {'doc_id': 4, 'TF_score': 0.125, 'key': 'it'},
#  {'doc_id': 4, 'TF_score': 0.125, 'key': 'is'},
#  {'doc_id': 4, 'TF_score': 0.125, 'key': 'not'},
#  {'doc_id': 4, 'TF_score': 0.125, 'key': 'clear'},
#  {'doc_id': 4, 'TF_score': 0.125, 'key': 'what'},
#  {'doc_id': 4, 'TF_score': 0.125, 'key': 'caused'},
#  {'doc_id': 4, 'TF_score': 0.125, 'key': 'the'},
#  {'doc_id': 4, 'TF_score': 0.125, 'key': 'explosion'},
#  {'doc_id': 5, 'TF_score': 0.05555555555555555, 'key': 'according'},
#  {'doc_id': 5, 'TF_score': 0.05555555555555555, 'key': 'to'},
#  {'doc_id': 5, 'TF_score': 0.05555555555555555, 'key': 'xinhua'},
#  {'doc_id': 5, 'TF_score': 0.05555555555555555, 'key': 'the'},
#  {'doc_id': 5, 'TF_score': 0.05555555555555555, 'key': 'fire'},
#  {'doc_id': 5, 'TF_score': 0.05555555555555555, 'key': 'which'},
#  {'doc_id': 5, 'TF_score': 0.05555555555555555, 'key': 'broke'},
#  {'doc_id': 5, 'TF_score': 0.1111111111111111, 'key': 'out'},
#  {'doc_id': 5, 'TF_score': 0.1111111111111111, 'key': 'on'},
#  {'doc_id': 5, 'TF_score': 0.05555555555555555, 'key': 'thursday'},
#  {'doc_id': 5, 'TF_score': 0.05555555555555555, 'key': 'evening'},
#  {'doc_id': 5, 'TF_score': 0.05555555555555555, 'key': 'had'},
#  {'doc_id': 5, 'TF_score': 0.05555555555555555, 'key': 'been'},
#  {'doc_id': 5, 'TF_score': 0.05555555555555555, 'key': 'put'},
#  {'doc_id': 5, 'TF_score': 0.05555555555555555, 'key': 'early'},
#  {'doc_id': 5, 'TF_score': 0.05555555555555555, 'key': 'friday'},
#  {'doc_id': 6, 'TF_score': 0.1, 'key': 'those'},
#  {'doc_id': 6, 'TF_score': 0.1, 'key': 'injured'},
#  {'doc_id': 6, 'TF_score': 0.2, 'key': 'in'},
#  {'doc_id': 6, 'TF_score': 0.1, 'key': 'the'},
#  {'doc_id': 6, 'TF_score': 0.1, 'key': 'blast'},
#  {'doc_id': 6, 'TF_score': 0.1, 'key': 'were'},
#  {'doc_id': 6, 'TF_score': 0.1, 'key': 'a'},
#  {'doc_id': 6, 'TF_score': 0.1, 'key': 'stable'},
#  {'doc_id': 6, 'TF_score': 0.1, 'key': 'condition'},
#  {'doc_id': 7, 'TF_score': 0.1111111111111111, 'key': 'authorities'},
#  {'doc_id': 7, 'TF_score': 0.1111111111111111, 'key': 'have'},
#  {'doc_id': 7, 'TF_score': 0.1111111111111111, 'key': 'begun'},
#  {'doc_id': 7, 'TF_score': 0.1111111111111111, 'key': 'an'},
#  {'doc_id': 7, 'TF_score': 0.1111111111111111, 'key': 'investigation'},
#  {'doc_id': 7, 'TF_score': 0.1111111111111111, 'key': 'the'},
#  {'doc_id': 7, 'TF_score': 0.1111111111111111, 'key': 'news'},
#  {'doc_id': 7, 'TF_score': 0.1111111111111111, 'key': 'agency'},
#  {'doc_id': 7, 'TF_score': 0.1111111111111111, 'key': 'said'},
#  {'doc_id': 8, 'TF_score': 0.1, 'key': 'yibin'},
#  {'doc_id': 8, 'TF_score': 0.1, 'key': 'hengda'},
#  {'doc_id': 8, 'TF_score': 0.1, 'key': 'makes'},
#  {'doc_id': 8, 'TF_score': 0.1, 'key': 'chemicals'},
#  {'doc_id': 8, 'TF_score': 0.1, 'key': 'for'},
#  {'doc_id': 8, 'TF_score': 0.1, 'key': 'the'},
#  {'doc_id': 8, 'TF_score': 0.1, 'key': 'food'},
#  {'doc_id': 8, 'TF_score': 0.1, 'key': 'and'},
#  {'doc_id': 8, 'TF_score': 0.1, 'key': 'pharmaceutical'},
#  {'doc_id': 8, 'TF_score': 0.1, 'key': 'industries'},
#  {'doc_id': 9, 'TF_score': 0.041666666666666664, 'key': 'according'},
#  {'doc_id': 9, 'TF_score': 0.08333333333333333, 'key': 'to'},
#  {'doc_id': 9, 'TF_score': 0.041666666666666664, 'key': 'local'},
#  {'doc_id': 9, 'TF_score': 0.041666666666666664, 'key': 'media'},
#  {'doc_id': 9, 'TF_score': 0.041666666666666664, 'key': 'reports'},
#  {'doc_id': 9, 'TF_score': 0.08333333333333333, 'key': 'the'},
#  {'doc_id': 9, 'TF_score': 0.041666666666666664, 'key': 'threestorey'},
#  {'doc_id': 9, 'TF_score': 0.08333333333333333, 'key': 'buildings'},
#  {'doc_id': 9, 'TF_score': 0.041666666666666664, 'key': 'of'},
#  {'doc_id': 9, 'TF_score': 0.041666666666666664, 'key': 'factory'},
#  {'doc_id': 9, 'TF_score': 0.041666666666666664, 'key': 'burnt'},
#  {'doc_id': 9, 'TF_score': 0.041666666666666664, 'key': 'down'},
#  {'doc_id': 9, 'TF_score': 0.08333333333333333, 'key': 'their'},
#  {'doc_id': 9, 'TF_score': 0.041666666666666664, 'key': 'steel'},
#  {'doc_id': 9, 'TF_score': 0.041666666666666664, 'key': 'frames'},
#  {'doc_id': 9, 'TF_score': 0.041666666666666664, 'key': 'and'},
#  {'doc_id': 9, 'TF_score': 0.041666666666666664, 'key': 'nearby'},
#  {'doc_id': 9, 'TF_score': 0.041666666666666664, 'key': 'had'},
#  {'doc_id': 9, 'TF_score': 0.041666666666666664, 'key': 'windows'},
#  {'doc_id': 9, 'TF_score': 0.041666666666666664, 'key': 'shattered'},
#  {'doc_id': 10, 'TF_score': 0.09090909090909091, 'key': 'the'},
#  {'doc_id': 10, 'TF_score': 0.09090909090909091, 'key': 'accident'},
#  {'doc_id': 10, 'TF_score': 0.09090909090909091, 'key': 'follows'},
#  {'doc_id': 10, 'TF_score': 0.09090909090909091, 'key': 'previous'},
#  {'doc_id': 10, 'TF_score': 0.09090909090909091, 'key': 'highprofile'},
#  {'doc_id': 10, 'TF_score': 0.09090909090909091, 'key': 'disasters'},
#  {'doc_id': 10, 'TF_score': 0.09090909090909091, 'key': 'at'},
#  {'doc_id': 10, 'TF_score': 0.09090909090909091, 'key': 'chemical'},
#  {'doc_id': 10, 'TF_score': 0.09090909090909091, 'key': 'plants'},
#  {'doc_id': 10, 'TF_score': 0.09090909090909091, 'key': 'in'},
#  {'doc_id': 10, 'TF_score': 0.09090909090909091, 'key': 'china'},
#  {'doc_id': 11, 'TF_score': 0.15789473684210525, 'key': 'in'},
#  {'doc_id': 11, 'TF_score': 0.05263157894736842, 'key': '2015'},
#  {'doc_id': 11, 'TF_score': 0.05263157894736842, 'key': '173'},
#  {'doc_id': 11, 'TF_score': 0.05263157894736842, 'key': 'people'},
#  {'doc_id': 11, 'TF_score': 0.05263157894736842, 'key': 'died'},
#  {'doc_id': 11, 'TF_score': 0.05263157894736842, 'key': 'an'},
#  {'doc_id': 11, 'TF_score': 0.05263157894736842, 'key': 'explosion'},
#  {'doc_id': 11, 'TF_score': 0.05263157894736842, 'key': 'at'},
#  {'doc_id': 11, 'TF_score': 0.05263157894736842, 'key': 'a'},
#  {'doc_id': 11, 'TF_score': 0.05263157894736842, 'key': 'chemical'},
#  {'doc_id': 11, 'TF_score': 0.05263157894736842, 'key': 'warehouse'},
#  {'doc_id': 11, 'TF_score': 0.05263157894736842, 'key': 'the'},
#  {'doc_id': 11, 'TF_score': 0.05263157894736842, 'key': 'northeastern'},
#  {'doc_id': 11, 'TF_score': 0.05263157894736842, 'key': 'port'},
#  {'doc_id': 11, 'TF_score': 0.05263157894736842, 'key': 'city'},
#  {'doc_id': 11, 'TF_score': 0.05263157894736842, 'key': 'of'},
#  {'doc_id': 11, 'TF_score': 0.05263157894736842, 'key': 'tianjin'},
#  {'doc_id': 12, 'TF_score': 0.04, 'key': 'an'},
#  {'doc_id': 12, 'TF_score': 0.08, 'key': 'official'},
#  {'doc_id': 12, 'TF_score': 0.04, 'key': 'investigation'},
#  {'doc_id': 12, 'TF_score': 0.04, 'key': 'into'},
#  {'doc_id': 12, 'TF_score': 0.04, 'key': 'the'},
#  {'doc_id': 12, 'TF_score': 0.04, 'key': 'blast'},
#  {'doc_id': 12, 'TF_score': 0.04, 'key': 'found'},
#  {'doc_id': 12, 'TF_score': 0.04, 'key': 'that'},
#  {'doc_id': 12, 'TF_score': 0.04, 'key': 'corruption'},
#  {'doc_id': 12, 'TF_score': 0.04, 'key': 'political'},
#  {'doc_id': 12, 'TF_score': 0.04, 'key': 'connections'},
#  {'doc_id': 12, 'TF_score': 0.08, 'key': 'and'},
#  {'doc_id': 12, 'TF_score': 0.04, 'key': 'collusion'},
#  {'doc_id': 12, 'TF_score': 0.04, 'key': 'allowed'},
#  {'doc_id': 12, 'TF_score': 0.04, 'key': 'corners'},
#  {'doc_id': 12, 'TF_score': 0.08, 'key': 'to'},
#  {'doc_id': 12, 'TF_score': 0.08, 'key': 'be'},
#  {'doc_id': 12, 'TF_score': 0.04, 'key': 'cut'},
#  {'doc_id': 12, 'TF_score': 0.04, 'key': 'safety'},
#  {'doc_id': 12, 'TF_score': 0.04, 'key': 'systems'},
#  {'doc_id': 12, 'TF_score': 0.04, 'key': 'overridden'}]

# %%
second_IDF_scores
# Out:
# [{'doc_id': 1, 'IDF_score': 1.0986122886681098, 'key': 'an'},
#  {'doc_id': 1, 'IDF_score': 1.3862943611198906, 'key': 'explosion'},
#  {'doc_id': 1, 'IDF_score': 1.0986122886681098, 'key': 'at'},
#  {'doc_id': 1, 'IDF_score': 2.4849066497880004, 'key': 'industrial'},
#  {'doc_id': 1, 'IDF_score': 2.4849066497880004, 'key': 'park'},
#  {'doc_id': 1, 'IDF_score': 0.8754687373538999, 'key': 'in'},
#  {'doc_id': 1, 'IDF_score': 2.4849066497880004, 'key': 'chinas'},
#  {'doc_id': 1, 'IDF_score': 2.4849066497880004, 'key': 'sichuan'},
#  {'doc_id': 1, 'IDF_score': 2.4849066497880004, 'key': 'province'},
#  {'doc_id': 1, 'IDF_score': 2.4849066497880004, 'key': 'has'},
#  {'doc_id': 1, 'IDF_score': 2.4849066497880004, 'key': 'left'},
#  {'doc_id': 1, 'IDF_score': 2.4849066497880004, 'key': '19'},
#  {'doc_id': 1, 'IDF_score': 1.791759469228055, 'key': 'people'},
#  {'doc_id': 1, 'IDF_score': 2.4849066497880004, 'key': 'dead'},
#  {'doc_id': 1, 'IDF_score': 0.8754687373538999, 'key': 'and'},
#  {'doc_id': 1, 'IDF_score': 2.4849066497880004, 'key': '12'},
#  {'doc_id': 1, 'IDF_score': 2.4849066497880004, 'key': 'others'},
#  {'doc_id': 1, 'IDF_score': 1.791759469228055, 'key': 'injured'},
#  {'doc_id': 1, 'IDF_score': 2.4849066497880004, 'key': 'officials'},
#  {'doc_id': 1, 'IDF_score': 2.4849066497880004, 'key': 'say'},
#  {'doc_id': 2, 'IDF_score': 0.8754687373538999, 'key': 'in'},
#  {'doc_id': 2, 'IDF_score': 1.0986122886681098, 'key': 'a'},
#  {'doc_id': 2, 'IDF_score': 2.4849066497880004, 'key': 'statement'},
#  {'doc_id': 2, 'IDF_score': 2.4849066497880004, 'key': 'quoted'},
#  {'doc_id': 2, 'IDF_score': 2.4849066497880004, 'key': 'by'},
#  {'doc_id': 2, 'IDF_score': 2.4849066497880004, 'key': 'reuters'},
#  {'doc_id': 2, 'IDF_score': 0.0870113769896297, 'key': 'the'},
#  {'doc_id': 2, 'IDF_score': 1.791759469228055, 'key': 'authorities'},
#  {'doc_id': 2, 'IDF_score': 2.4849066497880004, 'key': 'jiangan'},
#  {'doc_id': 2, 'IDF_score': 2.4849066497880004, 'key': 'county'},
#  {'doc_id': 2, 'IDF_score': 1.791759469228055, 'key': 'said'},
#  {'doc_id': 2, 'IDF_score': 1.3862943611198906, 'key': 'blast'},
#  {'doc_id': 2, 'IDF_score': 2.4849066497880004, 'key': 'happened'},
#  {'doc_id': 2, 'IDF_score': 1.0986122886681098, 'key': 'at'},
#  {'doc_id': 2, 'IDF_score': 1.3862943611198906, 'key': 'chemical'},
#  {'doc_id': 2, 'IDF_score': 2.4849066497880004, 'key': 'plant'},
#  {'doc_id': 2, 'IDF_score': 2.4849066497880004, 'key': 'run'},
#  {'doc_id': 2, 'IDF_score': 1.791759469228055, 'key': 'yibin'},
#  {'doc_id': 2, 'IDF_score': 1.791759469228055, 'key': 'hengda'},
#  {'doc_id': 2, 'IDF_score': 2.4849066497880004, 'key': 'technology'},
#  {'doc_id': 3, 'IDF_score': 2.4849066497880004, 'key': 'photos'},
#  {'doc_id': 3, 'IDF_score': 1.791759469228055, 'key': 'on'},
#  {'doc_id': 3, 'IDF_score': 2.4849066497880004, 'key': 'chinese'},
#  {'doc_id': 3, 'IDF_score': 2.4849066497880004, 'key': 'social'},
#  {'doc_id': 3, 'IDF_score': 1.791759469228055, 'key': 'media'},
#  {'doc_id': 3, 'IDF_score': 2.4849066497880004, 'key': 'showed'},
#  {'doc_id': 3, 'IDF_score': 1.0986122886681098, 'key': 'a'},
#  {'doc_id': 3, 'IDF_score': 2.4849066497880004, 'key': 'huge'},
#  {'doc_id': 3, 'IDF_score': 1.791759469228055, 'key': 'fire'},
#  {'doc_id': 3, 'IDF_score': 0.8754687373538999, 'key': 'and'},
#  {'doc_id': 3, 'IDF_score': 2.4849066497880004, 'key': 'plumes'},
#  {'doc_id': 3, 'IDF_score': 1.3862943611198906, 'key': 'of'},
#  {'doc_id': 3, 'IDF_score': 2.4849066497880004, 'key': 'smoke'},
#  {'doc_id': 3, 'IDF_score': 2.4849066497880004, 'key': 'rising'},
#  {'doc_id': 3, 'IDF_score': 2.4849066497880004, 'key': 'from'},
#  {'doc_id': 3, 'IDF_score': 0.0870113769896297, 'key': 'the'},
#  {'doc_id': 3, 'IDF_score': 2.4849066497880004, 'key': 'facility'},
#  {'doc_id': 4, 'IDF_score': 2.4849066497880004, 'key': 'it'},
#  {'doc_id': 4, 'IDF_score': 2.4849066497880004, 'key': 'is'},
#  {'doc_id': 4, 'IDF_score': 2.4849066497880004, 'key': 'not'},
#  {'doc_id': 4, 'IDF_score': 2.4849066497880004, 'key': 'clear'},
#  {'doc_id': 4, 'IDF_score': 2.4849066497880004, 'key': 'what'},
#  {'doc_id': 4, 'IDF_score': 2.4849066497880004, 'key': 'caused'},
#  {'doc_id': 4, 'IDF_score': 0.0870113769896297, 'key': 'the'},
#  {'doc_id': 4, 'IDF_score': 1.3862943611198906, 'key': 'explosion'},
#  {'doc_id': 5, 'IDF_score': 1.791759469228055, 'key': 'according'},
#  {'doc_id': 5, 'IDF_score': 1.3862943611198906, 'key': 'to'},
#  {'doc_id': 5, 'IDF_score': 2.4849066497880004, 'key': 'xinhua'},
#  {'doc_id': 5, 'IDF_score': 0.0870113769896297, 'key': 'the'},
#  {'doc_id': 5, 'IDF_score': 1.791759469228055, 'key': 'fire'},
#  {'doc_id': 5, 'IDF_score': 2.4849066497880004, 'key': 'which'},
#  {'doc_id': 5, 'IDF_score': 2.4849066497880004, 'key': 'broke'},
#  {'doc_id': 5, 'IDF_score': 2.4849066497880004, 'key': 'out'},
#  {'doc_id': 5, 'IDF_score': 1.791759469228055, 'key': 'on'},
#  {'doc_id': 5, 'IDF_score': 2.4849066497880004, 'key': 'thursday'},
#  {'doc_id': 5, 'IDF_score': 2.4849066497880004, 'key': 'evening'},
#  {'doc_id': 5, 'IDF_score': 1.791759469228055, 'key': 'had'},
#  {'doc_id': 5, 'IDF_score': 2.4849066497880004, 'key': 'been'},
#  {'doc_id': 5, 'IDF_score': 2.4849066497880004, 'key': 'put'},
#  {'doc_id': 5, 'IDF_score': 2.4849066497880004, 'key': 'early'},
#  {'doc_id': 5, 'IDF_score': 2.4849066497880004, 'key': 'friday'},
#  {'doc_id': 6, 'IDF_score': 2.4849066497880004, 'key': 'those'},
#  {'doc_id': 6, 'IDF_score': 1.791759469228055, 'key': 'injured'},
#  {'doc_id': 6, 'IDF_score': 0.8754687373538999, 'key': 'in'},
#  {'doc_id': 6, 'IDF_score': 0.0870113769896297, 'key': 'the'},
#  {'doc_id': 6, 'IDF_score': 1.3862943611198906, 'key': 'blast'},
#  {'doc_id': 6, 'IDF_score': 2.4849066497880004, 'key': 'were'},
#  {'doc_id': 6, 'IDF_score': 1.0986122886681098, 'key': 'a'},
#  {'doc_id': 6, 'IDF_score': 2.4849066497880004, 'key': 'stable'},
#  {'doc_id': 6, 'IDF_score': 2.4849066497880004, 'key': 'condition'},
#  {'doc_id': 7, 'IDF_score': 1.791759469228055, 'key': 'authorities'},
#  {'doc_id': 7, 'IDF_score': 2.4849066497880004, 'key': 'have'},
#  {'doc_id': 7, 'IDF_score': 2.4849066497880004, 'key': 'begun'},
#  {'doc_id': 7, 'IDF_score': 1.0986122886681098, 'key': 'an'},
#  {'doc_id': 7, 'IDF_score': 1.791759469228055, 'key': 'investigation'},
#  {'doc_id': 7, 'IDF_score': 0.0870113769896297, 'key': 'the'},
#  {'doc_id': 7, 'IDF_score': 2.4849066497880004, 'key': 'news'},
#  {'doc_id': 7, 'IDF_score': 2.4849066497880004, 'key': 'agency'},
#  {'doc_id': 7, 'IDF_score': 1.791759469228055, 'key': 'said'},
#  {'doc_id': 8, 'IDF_score': 1.791759469228055, 'key': 'yibin'},
#  {'doc_id': 8, 'IDF_score': 1.791759469228055, 'key': 'hengda'},
#  {'doc_id': 8, 'IDF_score': 2.4849066497880004, 'key': 'makes'},
#  {'doc_id': 8, 'IDF_score': 2.4849066497880004, 'key': 'chemicals'},
#  {'doc_id': 8, 'IDF_score': 2.4849066497880004, 'key': 'for'},
#  {'doc_id': 8, 'IDF_score': 0.0870113769896297, 'key': 'the'},
#  {'doc_id': 8, 'IDF_score': 2.4849066497880004, 'key': 'food'},
#  {'doc_id': 8, 'IDF_score': 0.8754687373538999, 'key': 'and'},
#  {'doc_id': 8, 'IDF_score': 2.4849066497880004, 'key': 'pharmaceutical'},
#  {'doc_id': 8, 'IDF_score': 2.4849066497880004, 'key': 'industries'},
#  {'doc_id': 9, 'IDF_score': 1.791759469228055, 'key': 'according'},
#  {'doc_id': 9, 'IDF_score': 1.3862943611198906, 'key': 'to'},
#  {'doc_id': 9, 'IDF_score': 2.4849066497880004, 'key': 'local'},
#  {'doc_id': 9, 'IDF_score': 1.791759469228055, 'key': 'media'},
#  {'doc_id': 9, 'IDF_score': 2.4849066497880004, 'key': 'reports'},
#  {'doc_id': 9, 'IDF_score': 0.0870113769896297, 'key': 'the'},
#  {'doc_id': 9, 'IDF_score': 2.4849066497880004, 'key': 'threestorey'},
#  {'doc_id': 9, 'IDF_score': 2.4849066497880004, 'key': 'buildings'},
#  {'doc_id': 9, 'IDF_score': 1.3862943611198906, 'key': 'of'},
#  {'doc_id': 9, 'IDF_score': 2.4849066497880004, 'key': 'factory'},
#  {'doc_id': 9, 'IDF_score': 2.4849066497880004, 'key': 'burnt'},
#  {'doc_id': 9, 'IDF_score': 2.4849066497880004, 'key': 'down'},
#  {'doc_id': 9, 'IDF_score': 2.4849066497880004, 'key': 'their'},
#  {'doc_id': 9, 'IDF_score': 2.4849066497880004, 'key': 'steel'},
#  {'doc_id': 9, 'IDF_score': 2.4849066497880004, 'key': 'frames'},
#  {'doc_id': 9, 'IDF_score': 0.8754687373538999, 'key': 'and'},
#  {'doc_id': 9, 'IDF_score': 2.4849066497880004, 'key': 'nearby'},
#  {'doc_id': 9, 'IDF_score': 1.791759469228055, 'key': 'had'},
#  {'doc_id': 9, 'IDF_score': 2.4849066497880004, 'key': 'windows'},
#  {'doc_id': 9, 'IDF_score': 2.4849066497880004, 'key': 'shattered'},
#  {'doc_id': 10, 'IDF_score': 0.0870113769896297, 'key': 'the'},
#  {'doc_id': 10, 'IDF_score': 2.4849066497880004, 'key': 'accident'},
#  {'doc_id': 10, 'IDF_score': 2.4849066497880004, 'key': 'follows'},
#  {'doc_id': 10, 'IDF_score': 2.4849066497880004, 'key': 'previous'},
#  {'doc_id': 10, 'IDF_score': 2.4849066497880004, 'key': 'highprofile'},
#  {'doc_id': 10, 'IDF_score': 2.4849066497880004, 'key': 'disasters'},
#  {'doc_id': 10, 'IDF_score': 1.0986122886681098, 'key': 'at'},
#  {'doc_id': 10, 'IDF_score': 1.3862943611198906, 'key': 'chemical'},
#  {'doc_id': 10, 'IDF_score': 2.4849066497880004, 'key': 'plants'},
#  {'doc_id': 10, 'IDF_score': 0.8754687373538999, 'key': 'in'},
#  {'doc_id': 10, 'IDF_score': 2.4849066497880004, 'key': 'china'},
#  {'doc_id': 11, 'IDF_score': 0.8754687373538999, 'key': 'in'},
#  {'doc_id': 11, 'IDF_score': 2.4849066497880004, 'key': '2015'},
#  {'doc_id': 11, 'IDF_score': 2.4849066497880004, 'key': '173'},
#  {'doc_id': 11, 'IDF_score': 1.791759469228055, 'key': 'people'},
#  {'doc_id': 11, 'IDF_score': 2.4849066497880004, 'key': 'died'},
#  {'doc_id': 11, 'IDF_score': 1.0986122886681098, 'key': 'an'},
#  {'doc_id': 11, 'IDF_score': 1.3862943611198906, 'key': 'explosion'},
#  {'doc_id': 11, 'IDF_score': 1.0986122886681098, 'key': 'at'},
#  {'doc_id': 11, 'IDF_score': 1.0986122886681098, 'key': 'a'},
#  {'doc_id': 11, 'IDF_score': 1.3862943611198906, 'key': 'chemical'},
#  {'doc_id': 11, 'IDF_score': 2.4849066497880004, 'key': 'warehouse'},
#  {'doc_id': 11, 'IDF_score': 0.0870113769896297, 'key': 'the'},
#  {'doc_id': 11, 'IDF_score': 2.4849066497880004, 'key': 'northeastern'},
#  {'doc_id': 11, 'IDF_score': 2.4849066497880004, 'key': 'port'},
#  {'doc_id': 11, 'IDF_score': 2.4849066497880004, 'key': 'city'},
#  {'doc_id': 11, 'IDF_score': 1.3862943611198906, 'key': 'of'},
#  {'doc_id': 11, 'IDF_score': 2.4849066497880004, 'key': 'tianjin'},
#  {'doc_id': 12, 'IDF_score': 1.0986122886681098, 'key': 'an'},
#  {'doc_id': 12, 'IDF_score': 2.4849066497880004, 'key': 'official'},
#  {'doc_id': 12, 'IDF_score': 1.791759469228055, 'key': 'investigation'},
#  {'doc_id': 12, 'IDF_score': 2.4849066497880004, 'key': 'into'},
#  {'doc_id': 12, 'IDF_score': 0.0870113769896297, 'key': 'the'},
#  {'doc_id': 12, 'IDF_score': 1.3862943611198906, 'key': 'blast'},
#  {'doc_id': 12, 'IDF_score': 2.4849066497880004, 'key': 'found'},
#  {'doc_id': 12, 'IDF_score': 2.4849066497880004, 'key': 'that'},
#  {'doc_id': 12, 'IDF_score': 2.4849066497880004, 'key': 'corruption'},
#  {'doc_id': 12, 'IDF_score': 2.4849066497880004, 'key': 'political'},
#  {'doc_id': 12, 'IDF_score': 2.4849066497880004, 'key': 'connections'},
#  {'doc_id': 12, 'IDF_score': 0.8754687373538999, 'key': 'and'},
#  {'doc_id': 12, 'IDF_score': 2.4849066497880004, 'key': 'collusion'},
#  {'doc_id': 12, 'IDF_score': 2.4849066497880004, 'key': 'allowed'},
#  {'doc_id': 12, 'IDF_score': 2.4849066497880004, 'key': 'corners'},
#  {'doc_id': 12, 'IDF_score': 1.3862943611198906, 'key': 'to'},
#  {'doc_id': 12, 'IDF_score': 2.4849066497880004, 'key': 'be'},
#  {'doc_id': 12, 'IDF_score': 2.4849066497880004, 'key': 'cut'},
#  {'doc_id': 12, 'IDF_score': 2.4849066497880004, 'key': 'safety'},
#  {'doc_id': 12, 'IDF_score': 2.4849066497880004, 'key': 'systems'},
#  {'doc_id': 12, 'IDF_score': 2.4849066497880004, 'key': 'overridden'}]

# %%
second_TFIDF_scores = computeTFIDF(second_TF_scores, second_IDF_scores)
second_TFIDF_scores
# Out:
# [{'doc_id': 1, 'TFIDF_score': 0.10462974177791522, 'key': 'an'},
#  {'doc_id': 1, 'TFIDF_score': 0.06601401719618526, 'key': 'explosion'},
#  {'doc_id': 1, 'TFIDF_score': 0.05231487088895761, 'key': 'at'},
#  {'doc_id': 1, 'TFIDF_score': 0.11832888808514287, 'key': 'industrial'},
#  {'doc_id': 1, 'TFIDF_score': 0.11832888808514287, 'key': 'park'},
#  {'doc_id': 1, 'TFIDF_score': 0.041688987493042846, 'key': 'in'},
#  {'doc_id': 1, 'TFIDF_score': 0.11832888808514287, 'key': 'chinas'},
#  {'doc_id': 1, 'TFIDF_score': 0.11832888808514287, 'key': 'sichuan'},
#  {'doc_id': 1, 'TFIDF_score': 0.11832888808514287, 'key': 'province'},
#  {'doc_id': 1, 'TFIDF_score': 0.11832888808514287, 'key': 'has'},
#  {'doc_id': 1, 'TFIDF_score': 0.11832888808514287, 'key': 'left'},
#  {'doc_id': 1, 'TFIDF_score': 0.11832888808514287, 'key': '19'},
#  {'doc_id': 1, 'TFIDF_score': 0.08532187948705024, 'key': 'people'},
#  {'doc_id': 1, 'TFIDF_score': 0.11832888808514287, 'key': 'dead'},
#  {'doc_id': 1, 'TFIDF_score': 0.041688987493042846, 'key': 'and'},
#  {'doc_id': 1, 'TFIDF_score': 0.11832888808514287, 'key': '12'},
#  {'doc_id': 1, 'TFIDF_score': 0.11832888808514287, 'key': 'others'},
#  {'doc_id': 1, 'TFIDF_score': 0.08532187948705024, 'key': 'injured'},
#  {'doc_id': 1, 'TFIDF_score': 0.11832888808514287, 'key': 'officials'},
#  {'doc_id': 1, 'TFIDF_score': 0.11832888808514287, 'key': 'say'},
#  {'doc_id': 2, 'TFIDF_score': 0.07295572811282498, 'key': 'in'},
#  {'doc_id': 2, 'TFIDF_score': 0.0915510240556758, 'key': 'a'},
#  {'doc_id': 2, 'TFIDF_score': 0.10353777707450001, 'key': 'statement'},
#  {'doc_id': 2, 'TFIDF_score': 0.10353777707450001, 'key': 'quoted'},
#  {'doc_id': 2, 'TFIDF_score': 0.20707555414900003, 'key': 'by'},
#  {'doc_id': 2, 'TFIDF_score': 0.10353777707450001, 'key': 'reuters'},
#  {'doc_id': 2, 'TFIDF_score': 0.007250948082469141, 'key': 'the'},
#  {'doc_id': 2, 'TFIDF_score': 0.07465664455116895, 'key': 'authorities'},
#  {'doc_id': 2, 'TFIDF_score': 0.10353777707450001, 'key': 'jiangan'},
#  {'doc_id': 2, 'TFIDF_score': 0.10353777707450001, 'key': 'county'},
#  {'doc_id': 2, 'TFIDF_score': 0.07465664455116895, 'key': 'said'},
#  {'doc_id': 2, 'TFIDF_score': 0.057762265046662105, 'key': 'blast'},
#  {'doc_id': 2, 'TFIDF_score': 0.10353777707450001, 'key': 'happened'},
#  {'doc_id': 2, 'TFIDF_score': 0.0457755120278379, 'key': 'at'},
#  {'doc_id': 2, 'TFIDF_score': 0.057762265046662105, 'key': 'chemical'},
#  {'doc_id': 2, 'TFIDF_score': 0.10353777707450001, 'key': 'plant'},
#  {'doc_id': 2, 'TFIDF_score': 0.10353777707450001, 'key': 'run'},
#  {'doc_id': 2, 'TFIDF_score': 0.07465664455116895, 'key': 'yibin'},
#  {'doc_id': 2, 'TFIDF_score': 0.07465664455116895, 'key': 'hengda'},
#  {'doc_id': 2, 'TFIDF_score': 0.10353777707450001, 'key': 'technology'},
#  {'doc_id': 3, 'TFIDF_score': 0.14617097939929413, 'key': 'photos'},
#  {'doc_id': 3, 'TFIDF_score': 0.1053976158369444, 'key': 'on'},
#  {'doc_id': 3, 'TFIDF_score': 0.14617097939929413, 'key': 'chinese'},
#  {'doc_id': 3, 'TFIDF_score': 0.14617097939929413, 'key': 'social'},
#  {'doc_id': 3, 'TFIDF_score': 0.1053976158369444, 'key': 'media'},
#  {'doc_id': 3, 'TFIDF_score': 0.14617097939929413, 'key': 'showed'},
#  {'doc_id': 3, 'TFIDF_score': 0.06462425227459469, 'key': 'a'},
#  {'doc_id': 3, 'TFIDF_score': 0.14617097939929413, 'key': 'huge'},
#  {'doc_id': 3, 'TFIDF_score': 0.1053976158369444, 'key': 'fire'},
#  {'doc_id': 3, 'TFIDF_score': 0.05149816102081764, 'key': 'and'},
#  {'doc_id': 3, 'TFIDF_score': 0.14617097939929413, 'key': 'plumes'},
#  {'doc_id': 3, 'TFIDF_score': 0.08154672712469944, 'key': 'of'},
#  {'doc_id': 3, 'TFIDF_score': 0.14617097939929413, 'key': 'smoke'},
#  {'doc_id': 3, 'TFIDF_score': 0.14617097939929413, 'key': 'rising'},
#  {'doc_id': 3, 'TFIDF_score': 0.14617097939929413, 'key': 'from'},
#  {'doc_id': 3, 'TFIDF_score': 0.005118316293507629, 'key': 'the'},
#  {'doc_id': 3, 'TFIDF_score': 0.14617097939929413, 'key': 'facility'},
#  {'doc_id': 4, 'TFIDF_score': 0.31061333122350004, 'key': 'it'},
#  {'doc_id': 4, 'TFIDF_score': 0.31061333122350004, 'key': 'is'},
#  {'doc_id': 4, 'TFIDF_score': 0.31061333122350004, 'key': 'not'},
#  {'doc_id': 4, 'TFIDF_score': 0.31061333122350004, 'key': 'clear'},
#  {'doc_id': 4, 'TFIDF_score': 0.31061333122350004, 'key': 'what'},
#  {'doc_id': 4, 'TFIDF_score': 0.31061333122350004, 'key': 'caused'},
#  {'doc_id': 4, 'TFIDF_score': 0.010876422123703712, 'key': 'the'},
#  {'doc_id': 4, 'TFIDF_score': 0.17328679513998632, 'key': 'explosion'},
#  {'doc_id': 5, 'TFIDF_score': 0.09954219273489194, 'key': 'according'},
#  {'doc_id': 5, 'TFIDF_score': 0.07701635339554948, 'key': 'to'},
#  {'doc_id': 5, 'TFIDF_score': 0.1380503694326667, 'key': 'xinhua'},
#  {'doc_id': 5, 'TFIDF_score': 0.00483396538831276, 'key': 'the'},
#  {'doc_id': 5, 'TFIDF_score': 0.09954219273489194, 'key': 'fire'},
#  {'doc_id': 5, 'TFIDF_score': 0.1380503694326667, 'key': 'which'},
#  {'doc_id': 5, 'TFIDF_score': 0.1380503694326667, 'key': 'broke'},
#  {'doc_id': 5, 'TFIDF_score': 0.2761007388653334, 'key': 'out'},
#  {'doc_id': 5, 'TFIDF_score': 0.19908438546978388, 'key': 'on'},
#  {'doc_id': 5, 'TFIDF_score': 0.1380503694326667, 'key': 'thursday'},
#  {'doc_id': 5, 'TFIDF_score': 0.1380503694326667, 'key': 'evening'},
#  {'doc_id': 5, 'TFIDF_score': 0.09954219273489194, 'key': 'had'},
#  {'doc_id': 5, 'TFIDF_score': 0.1380503694326667, 'key': 'been'},
#  {'doc_id': 5, 'TFIDF_score': 0.1380503694326667, 'key': 'put'},
#  {'doc_id': 5, 'TFIDF_score': 0.1380503694326667, 'key': 'early'},
#  {'doc_id': 5, 'TFIDF_score': 0.1380503694326667, 'key': 'friday'},
#  {'doc_id': 6, 'TFIDF_score': 0.24849066497880004, 'key': 'those'},
#  {'doc_id': 6, 'TFIDF_score': 0.1791759469228055, 'key': 'injured'},
#  {'doc_id': 6, 'TFIDF_score': 0.17509374747078, 'key': 'in'},
#  {'doc_id': 6, 'TFIDF_score': 0.00870113769896297, 'key': 'the'},
#  {'doc_id': 6, 'TFIDF_score': 0.13862943611198905, 'key': 'blast'},
#  {'doc_id': 6, 'TFIDF_score': 0.24849066497880004, 'key': 'were'},
#  {'doc_id': 6, 'TFIDF_score': 0.10986122886681099, 'key': 'a'},
#  {'doc_id': 6, 'TFIDF_score': 0.24849066497880004, 'key': 'stable'},
#  {'doc_id': 6, 'TFIDF_score': 0.24849066497880004, 'key': 'condition'},
#  {'doc_id': 7, 'TFIDF_score': 0.19908438546978388, 'key': 'authorities'},
#  {'doc_id': 7, 'TFIDF_score': 0.2761007388653334, 'key': 'have'},
#  {'doc_id': 7, 'TFIDF_score': 0.2761007388653334, 'key': 'begun'},
#  {'doc_id': 7, 'TFIDF_score': 0.12206803207423442, 'key': 'an'},
#  {'doc_id': 7, 'TFIDF_score': 0.19908438546978388, 'key': 'investigation'},
#  {'doc_id': 7, 'TFIDF_score': 0.00966793077662552, 'key': 'the'},
#  {'doc_id': 7, 'TFIDF_score': 0.2761007388653334, 'key': 'news'},
#  {'doc_id': 7, 'TFIDF_score': 0.2761007388653334, 'key': 'agency'},
#  {'doc_id': 7, 'TFIDF_score': 0.19908438546978388, 'key': 'said'},
#  {'doc_id': 8, 'TFIDF_score': 0.1791759469228055, 'key': 'yibin'},
#  {'doc_id': 8, 'TFIDF_score': 0.1791759469228055, 'key': 'hengda'},
#  {'doc_id': 8, 'TFIDF_score': 0.24849066497880004, 'key': 'makes'},
#  {'doc_id': 8, 'TFIDF_score': 0.24849066497880004, 'key': 'chemicals'},
#  {'doc_id': 8, 'TFIDF_score': 0.24849066497880004, 'key': 'for'},
#  {'doc_id': 8, 'TFIDF_score': 0.00870113769896297, 'key': 'the'},
#  {'doc_id': 8, 'TFIDF_score': 0.24849066497880004, 'key': 'food'},
#  {'doc_id': 8, 'TFIDF_score': 0.08754687373539, 'key': 'and'},
#  {'doc_id': 8, 'TFIDF_score': 0.24849066497880004, 'key': 'pharmaceutical'},
#  {'doc_id': 8, 'TFIDF_score': 0.24849066497880004, 'key': 'industries'},
#  {'doc_id': 9, 'TFIDF_score': 0.07465664455116895, 'key': 'according'},
#  {'doc_id': 9, 'TFIDF_score': 0.11552453009332421, 'key': 'to'},
#  {'doc_id': 9, 'TFIDF_score': 0.10353777707450001, 'key': 'local'},
#  {'doc_id': 9, 'TFIDF_score': 0.07465664455116895, 'key': 'media'},
#  {'doc_id': 9, 'TFIDF_score': 0.10353777707450001, 'key': 'reports'},
#  {'doc_id': 9, 'TFIDF_score': 0.007250948082469141, 'key': 'the'},
#  {'doc_id': 9, 'TFIDF_score': 0.10353777707450001, 'key': 'threestorey'},
#  {'doc_id': 9, 'TFIDF_score': 0.20707555414900003, 'key': 'buildings'},
#  {'doc_id': 9, 'TFIDF_score': 0.057762265046662105, 'key': 'of'},
#  {'doc_id': 9, 'TFIDF_score': 0.10353777707450001, 'key': 'factory'},
#  {'doc_id': 9, 'TFIDF_score': 0.10353777707450001, 'key': 'burnt'},
#  {'doc_id': 9, 'TFIDF_score': 0.10353777707450001, 'key': 'down'},
#  {'doc_id': 9, 'TFIDF_score': 0.20707555414900003, 'key': 'their'},
#  {'doc_id': 9, 'TFIDF_score': 0.10353777707450001, 'key': 'steel'},
#  {'doc_id': 9, 'TFIDF_score': 0.10353777707450001, 'key': 'frames'},
#  {'doc_id': 9, 'TFIDF_score': 0.03647786405641249, 'key': 'and'},
#  {'doc_id': 9, 'TFIDF_score': 0.10353777707450001, 'key': 'nearby'},
#  {'doc_id': 9, 'TFIDF_score': 0.07465664455116895, 'key': 'had'},
#  {'doc_id': 9, 'TFIDF_score': 0.10353777707450001, 'key': 'windows'},
#  {'doc_id': 9, 'TFIDF_score': 0.10353777707450001, 'key': 'shattered'},
#  {'doc_id': 10, 'TFIDF_score': 0.007910125180875428, 'key': 'the'},
#  {'doc_id': 10, 'TFIDF_score': 0.22590060452618185, 'key': 'accident'},
#  {'doc_id': 10, 'TFIDF_score': 0.22590060452618185, 'key': 'follows'},
#  {'doc_id': 10, 'TFIDF_score': 0.22590060452618185, 'key': 'previous'},
#  {'doc_id': 10, 'TFIDF_score': 0.22590060452618185, 'key': 'highprofile'},
#  {'doc_id': 10, 'TFIDF_score': 0.22590060452618185, 'key': 'disasters'},
#  {'doc_id': 10, 'TFIDF_score': 0.09987384442437362, 'key': 'at'},
#  {'doc_id': 10, 'TFIDF_score': 0.12602676010180824, 'key': 'chemical'},
#  {'doc_id': 10, 'TFIDF_score': 0.22590060452618185, 'key': 'plants'},
#  {'doc_id': 10, 'TFIDF_score': 0.07958806703217272, 'key': 'in'},
#  {'doc_id': 10, 'TFIDF_score': 0.22590060452618185, 'key': 'china'},
#  {'doc_id': 11, 'TFIDF_score': 0.13823190589798418, 'key': 'in'},
#  {'doc_id': 11, 'TFIDF_score': 0.1307845605151579, 'key': '2015'},
#  {'doc_id': 11, 'TFIDF_score': 0.1307845605151579, 'key': '173'},
#  {'doc_id': 11, 'TFIDF_score': 0.0943031299593713, 'key': 'people'},
#  {'doc_id': 11, 'TFIDF_score': 0.1307845605151579, 'key': 'died'},
#  {'doc_id': 11, 'TFIDF_score': 0.057821699403584725, 'key': 'an'},
#  {'doc_id': 11, 'TFIDF_score': 0.07296286111157319, 'key': 'explosion'},
#  {'doc_id': 11, 'TFIDF_score': 0.057821699403584725, 'key': 'at'},
#  {'doc_id': 11, 'TFIDF_score': 0.057821699403584725, 'key': 'a'},
#  {'doc_id': 11, 'TFIDF_score': 0.07296286111157319, 'key': 'chemical'},
#  {'doc_id': 11, 'TFIDF_score': 0.1307845605151579, 'key': 'warehouse'},
#  {'doc_id': 11, 'TFIDF_score': 0.004579546157348931, 'key': 'the'},
#  {'doc_id': 11, 'TFIDF_score': 0.1307845605151579, 'key': 'northeastern'},
#  {'doc_id': 11, 'TFIDF_score': 0.1307845605151579, 'key': 'port'},
#  {'doc_id': 11, 'TFIDF_score': 0.1307845605151579, 'key': 'city'},
#  {'doc_id': 11, 'TFIDF_score': 0.07296286111157319, 'key': 'of'},
#  {'doc_id': 11, 'TFIDF_score': 0.1307845605151579, 'key': 'tianjin'},
#  {'doc_id': 12, 'TFIDF_score': 0.04394449154672439, 'key': 'an'},
#  {'doc_id': 12, 'TFIDF_score': 0.19879253198304003, 'key': 'official'},
#  {'doc_id': 12, 'TFIDF_score': 0.0716703787691222, 'key': 'investigation'},
#  {'doc_id': 12, 'TFIDF_score': 0.09939626599152002, 'key': 'into'},
#  {'doc_id': 12, 'TFIDF_score': 0.003480455079585188, 'key': 'the'},
#  {'doc_id': 12, 'TFIDF_score': 0.055451774444795626, 'key': 'blast'},
#  {'doc_id': 12, 'TFIDF_score': 0.09939626599152002, 'key': 'found'},
#  {'doc_id': 12, 'TFIDF_score': 0.09939626599152002, 'key': 'that'},
#  {'doc_id': 12, 'TFIDF_score': 0.09939626599152002, 'key': 'corruption'},
#  {'doc_id': 12, 'TFIDF_score': 0.09939626599152002, 'key': 'political'},
#  {'doc_id': 12, 'TFIDF_score': 0.09939626599152002, 'key': 'connections'},
#  {'doc_id': 12, 'TFIDF_score': 0.07003749898831199, 'key': 'and'},
#  {'doc_id': 12, 'TFIDF_score': 0.09939626599152002, 'key': 'collusion'},
#  {'doc_id': 12, 'TFIDF_score': 0.09939626599152002, 'key': 'allowed'},
#  {'doc_id': 12, 'TFIDF_score': 0.09939626599152002, 'key': 'corners'},
#  {'doc_id': 12, 'TFIDF_score': 0.11090354888959125, 'key': 'to'},
#  {'doc_id': 12, 'TFIDF_score': 0.19879253198304003, 'key': 'be'},
#  {'doc_id': 12, 'TFIDF_score': 0.09939626599152002, 'key': 'cut'},
#  {'doc_id': 12, 'TFIDF_score': 0.09939626599152002, 'key': 'safety'},
#  {'doc_id': 12, 'TFIDF_score': 0.09939626599152002, 'key': 'systems'},
#  {'doc_id': 12, 'TFIDF_score': 0.09939626599152002, 'key': 'overridden'}]

# %%
def get_sent_score(TFIDF_scores, text_sents, doc_info):
    """
    This function prints out the summary and reutrns the
    score of each sentence in a list.
    
    The score of a sentence is calculated by adding the TFIDF
    scores of the words that make up the sentence.
    """
    sentence_info = []
    for doc in doc_info:
        """
        This loops through each document(sentence)
        and calculates their 'sent_score'
        """
        sent_score = 0
        for i in range(0, len(TFIDF_scores)):
            temp_dict = TFIDF_scores[i]
            #print(temp_dict['TFIDF_score'])
            #print(doc['doc_id'])
            if doc['doc_id'] == temp_dict['doc_id']:
                sent_score += temp_dict['TFIDF_score']
        temp = {'doc_id': doc['doc_id'], 'sent_score':sent_score,
               'sentence':text_sents[doc['doc_id']-1]}
        sentence_info.append(temp)
        
    return sentence_info

# %%
sentence_info = get_sent_score(second_TFIDF_scores, second_text_sents, second_doc_info)
sentence_info
# Out:
# [{'doc_id': 1,
#   'sent_score': 2.015255908930102,
#   'sentence': "An explosion at an industrial park in China's Sichuan province has left 19 people dead and 12 others injured, officials say."},
#  {'doc_id': 2,
#   'sent_score': 1.7705998683963082,
#   'sentence': "In a statement quoted by Reuters, the authorities in Jiang'an county said the blast happened at a chemical plant run by Yibin Hengda Technology."},
#  {'doc_id': 3,
#   'sent_score': 1.9806900982173943,
#   'sentence': 'Photos on Chinese social media showed a huge fire and plumes of smoke rising from the facility.'},
#  {'doc_id': 4,
#   'sent_score': 2.04784320460469,
#   'sentence': 'It is not clear what caused the explosion.'},
#  {'doc_id': 5,
#   'sent_score': 2.0981153462176554,
#   'sentence': 'According to Xinhua the fire, which broke out on Thursday evening, had been put out early on Friday.'},
#  {'doc_id': 6,
#   'sent_score': 1.6054241569865488,
#   'sentence': 'Those injured in the blast were in a stable condition.'},
#  {'doc_id': 7,
#   'sent_score': 1.833392074721545,
#   'sentence': 'Authorities have begun an investigation, the news agency said.'},
#  {'doc_id': 8,
#   'sent_score': 1.9455438951527644,
#   'sentence': 'Yibin Hengda makes chemicals for the food and pharmaceutical industries.'},
#  {'doc_id': 9,
#   'sent_score': 1.9940521970498757,
#   'sentence': 'According to local media reports, the three-storey buildings of the factory burnt down to their steel frames and nearby buildings had their windows shattered.'},
#  {'doc_id': 10,
#   'sent_score': 1.8947030284225026,
#   'sentence': 'The accident follows previous high-profile disasters at chemical plants in China.'},
#  {'doc_id': 11,
#   'sent_score': 1.675744747681441,
#   'sentence': 'In 2015, 173 people died in an explosion at a chemical warehouse in the north-eastern port city of Tianjin.'},
#  {'doc_id': 12,
#   'sent_score': 2.04522466957397,
#   'sentence': 'An official investigation into the blast found that corruption, political connections and official collusion allowed corners to be cut and safety systems to be overridden.'}]

# %% [markdown]
# https://www.youtube.com/watch?v=hXNbFNCgPfY
# https://www.youtube.com/watch?v=BJ0MnawUpaU
